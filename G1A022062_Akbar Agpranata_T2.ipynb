# %%
class Mahasiswa:
    def __init__(self, nama, npm, jurusan):
        self.nama = nama
        self.npm = npm
        self.jurusan = jurusan

    def tampilkan_info(self):
        print("Nama: ", self.nama)
        print("NPM: ", self.npm)
        print("Jurusan: ", self.jurusan.NamaJurusan, "\n")


class Jurusan:
    def __init__(self, nama_jurusan):
        self.NamaJurusan = nama_jurusan
        self.DaftarMahasiswa = []

    def tambah_mahasiswa(self, mahasiswa):
        self.DaftarMahasiswa.append(mahasiswa)

    def tampilkan_daftar_mahasiswa(self):
        print("\n","Daftar Mahasiswa di Jurusan", self.NamaJurusan, ":")
        for mahasiswa in self.DaftarMahasiswa:
            print(mahasiswa.nama)


class Universitas:
    def __init__(self, nama_universitas):
        self.NamaUniversitas = nama_universitas
        self.DaftarJurusan = []

    def tambah_jurusan(self, jurusan):
        self.DaftarJurusan.append(jurusan)

    def tampilkan_daftar_jurusan(self):
        print("Daftar Jurusan di Universitas ", self.NamaUniversitas)
        for jurusan in self.DaftarJurusan:
            print(jurusan.NamaJurusan)


# Penggunaan Program:
# Membuat objek Jurusan
informatika = Jurusan("Teknik Informatika")
matematika = Jurusan("Matematika")

# Membuat objek Mahasiswa
mahasiswa1 = Mahasiswa("Akbar Agpranata", "G1A022062", informatika)
mahasiswa2 = Mahasiswa("Ludia Saqina", "F1A07122003", matematika)

# Menambahkan Mahasiswa ke Jurusan
informatika.tambah_mahasiswa(mahasiswa1)
matematika.tambah_mahasiswa(mahasiswa2)

# Membuat objek Universitas
universitas = Universitas("XYZ University :")

# Menambahkan Jurusan ke Universitas
universitas.tambah_jurusan(informatika)
universitas.tambah_jurusan(matematika)

# Menampilkan informasi Mahasiswa
mahasiswa1.tampilkan_info()
mahasiswa2.tampilkan_info()

# Menampilkan daftar Jurusan di Universitas
universitas.tampilkan_daftar_jurusan()

# Menampilkan daftar Mahasiswa di Jurusan
informatika.tampilkan_daftar_mahasiswa()
matematika.tampilkan_daftar_mahasiswa()
# Out:
# Nama:  Akbar Agpranata
# NPM:  G1A022062
# Jurusan:  Teknik Informatika
#
# Nama:  Ludia Saqina
# NPM:  F1A07122003
# Jurusan:  Matematika
#
# Daftar Jurusan di Universitas  XYZ University :
# Teknik Informatika
# Matematika
#
#  Daftar Mahasiswa di Jurusan Teknik Informatika :
# Akbar Agpranata
#
#  Daftar Mahasiswa di Jurusan Matematika :
# Ludia Saqina

# %% [markdown]
# # New Section
